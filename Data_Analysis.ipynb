# %%
# Importing Libraries

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os

# %%
# Connecting with dataset

dataset = pd.read_csv('Resources/world-happiness-report-2021.csv')

dataset.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
# Making a copy of the dataset

dataset_modified = dataset.copy()
dataset_modified
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
# Checking the data types

dataset_modified.dtypes
# Out:
# Country name                                   object
# Regional indicator                             object
# Ladder score                                  float64
# Standard error of ladder score                float64
# upperwhisker                                  float64
# lowerwhisker                                  float64
# Logged GDP per capita                         float64
# Social support                                float64
# Healthy life expectancy                       float64
# Freedom to make life choices                  float64
# Generosity                                    float64
# Perceptions of corruption                     float64
# Ladder score in Dystopia                      float64
# Explained by: Log GDP per capita              float64
# Explained by: Social support                  float64
# Explained by: Healthy life expectancy         float64
# Explained by: Freedom to make life choices    float64
# ...

# %%
# Rounding to two decimal points

dataset_modified = dataset_modified.round(2)

dataset_modified.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe          7.84
# 1      Denmark     Western Europe          7.62
# 2  Switzerland     Western Europe          7.57
# 3      Iceland     Western Europe          7.55
# 4  Netherlands     Western Europe          7.46
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                            0.03          7.90          7.78
# 1                            0.04          7.69          7.55
# 2                            0.04          7.64          7.50
# 3                            0.06          7.67          7.44
# 4                            0.03          7.52          7.41
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                  10.78            0.95                     72.0
# 1                  10.93            0.95                     72.7
# 2                  11.12            0.94                     74.4
# ...

# %%
# Renaming the columns

dataset_modified = dataset_modified.rename(columns={"Regional indicator": "Region", "Ladder score": "Score", "Logged GDP per capita": "GDP per capita", "Social support": "Social Support", "Healthy life expectancy": "Life Expectancy", "Freedom to make life choices": "Freedom", "Perceptions of corruption": "Corruption Score"})

dataset_modified.head()
# Out:
#   Country name          Region  Score  Standard error of ladder score  \
# 0      Finland  Western Europe   7.84                            0.03
# 1      Denmark  Western Europe   7.62                            0.04
# 2  Switzerland  Western Europe   7.57                            0.04
# 3      Iceland  Western Europe   7.55                            0.06
# 4  Netherlands  Western Europe   7.46                            0.03
#
#    upperwhisker  lowerwhisker  GDP per capita  Social Support  \
# 0          7.90          7.78           10.78            0.95
# 1          7.69          7.55           10.93            0.95
# 2          7.64          7.50           11.12            0.94
# 3          7.67          7.44           10.88            0.98
# 4          7.52          7.41           10.93            0.94
#
#    Life Expectancy  Freedom  Generosity  Corruption Score  \
# 0             72.0     0.95       -0.10              0.19
# ...

# %%
# Scatter plot of Score vs GDP per capita

fig = plt.gcf()

fig.set_size_inches(16, 8)

sns.set_style("darkgrid")

sns.scatterplot(data=dataset_modified, x='Score', y='GDP per capita', hue='Region', size='GDP per capita').set(title='Score vs GDP per capita')
# Out:
# [Text(0.5, 1.0, 'Score vs GDP per capita')]

# %%
# Scatter plot of Score vs Social Support

fig = plt.gcf()

fig.set_size_inches(15, 8)

sns.set_style("darkgrid")

sns.scatterplot(data=dataset_modified, x='Score', y='Social Support', hue='Region', size='Social Support').set(title='Score vs Social Support')
# Out:
# [Text(0.5, 1.0, 'Score vs Social Support')]

# %%
# Scatter plot of Score vs Life Expectancy

fig = plt.gcf()

fig.set_size_inches(23, 8)

sns.set_style("darkgrid")

sns.scatterplot(data=dataset_modified, x='Score', y='Life Expectancy', hue='Region', size='Life Expectancy').set(title='Score vs Life Expectancy')
# Out:
# [Text(0.5, 1.0, 'Score vs Life Expectancy')]

# %%
# Scatter plot of Score vs Freedom

fig = plt.gcf()

fig.set_size_inches(21, 8)

sns.set_style("darkgrid")

sns.scatterplot(data=dataset_modified, x='Score', y='Freedom', hue='Region', size='Freedom').set(title='Score vs Freedom')
# Out:
# [Text(0.5, 1.0, 'Score vs Freedom')]

# %%
# Scatter plot of Score vs Generosity

fig = plt.gcf()

fig.set_size_inches(22, 8)

sns.set_style("darkgrid")

sns.scatterplot(data=dataset_modified, x='Score', y='Generosity', hue='Region', size='Generosity').set(title='Score vs Generosity')
# Out:
# [Text(0.5, 1.0, 'Score vs Generosity')]

# %%
# Scatter plot of Score vs Corruption

fig = plt.gcf()

fig.set_size_inches(20, 8)

sns.set_style("darkgrid")

sns.scatterplot(data=dataset_modified, x='Score', y='Corruption Score', hue='Region', size='Corruption Score').set(title='Score vs Corruption Score')
# Out:
# [Text(0.5, 1.0, 'Score vs Corruption Score')]

# %%
# Bar plot of Regions vs Score 

fig = plt.gcf()

fig.set_size_inches(30, 10)

sns.set_style("darkgrid")

ax = sns.barplot(x='Region', y='Score', hue='Region', data=dataset_modified, dodge=False)
